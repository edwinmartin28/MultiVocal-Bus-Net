# %% [markdown]
# <a href="https://colab.research.google.com/github/edwinmartin28/MultiVocal-Bus-Net/blob/main/KSRTC_License_Plate_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown  # Importing the gdown library for downloading files from Google Drive
import zipfile  # Importing the zipfile library for extracting zip files
from PIL import Image  # Importing the Image module from the Pillow library for image processing
import os  # Importing the os module for interacting with the operating system

# URL of the dataset to be downloaded
url = 'https://drive.google.com/uc?id=1JbSKecaPc_qUcZoH07M-LR6R5Z4Mtj5F'

# Path where the downloaded zip file will be saved
output_zip = '/content/dataset.zip'

# Download the dataset from the specified URL and save it to the specified location
gdown.download(url, output_zip, quiet=False)

# Extract the contents of the downloaded zip file
with zipfile.ZipFile(output_zip, 'r') as zip_ref:
    zip_ref.extractall('/content/')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JbSKecaPc_qUcZoH07M-LR6R5Z4Mtj5F
# From (redirected): https://drive.google.com/uc?id=1JbSKecaPc_qUcZoH07M-LR6R5Z4Mtj5F&confirm=t&uuid=904aeff1-dce6-458b-a567-499e56569a1b
# To: /content/dataset.zip
# 100%|██████████| 56.6M/56.6M [00:01<00:00, 33.8MB/s]

# %%
# !pip install ultralytics # Install the ultralytics library using pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 8.9 MB/s eta 0:00:00
# ...

# %%
# Command to train a YOLO (You Only Look Once) object detection model
# !yolo train model=yolov8n.pt data=/content/KSRTC-Dataset-Split/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 107MB/s]
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/runs/detect/train/weights/best.pt source='/content/KSRTC-Dataset-Split/test/images/'
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/37 /content/KSRTC-Dataset-Split/test/images/Img_132.jpg: 640x640 1 LicensePlate, 24.0ms
# image 2/37 /content/KSRTC-Dataset-Split/test/images/Img_148.jpg: 640x640 1 LicensePlate, 10.4ms
# image 3/37 /content/KSRTC-Dataset-Split/test/images/Img_15.jpg: 640x640 2 LicensePlates, 7.9ms
# image 4/37 /content/KSRTC-Dataset-Split/test/images/Img_153.jpg: 640x640 1 LicensePlate, 9.0ms
# image 5/37 /content/KSRTC-Dataset-Split/test/images/Img_190.jpg: 640x640 1 LicensePlate, 7.5ms
# image 6/37 /content/KSRTC-Dataset-Split/test/images/Img_249.jpg: 640x640 1 LicensePlate, 7.3ms
# image 7/37 /content/KSRTC-Dataset-Split/test/images/Img_298.jpg: 640x640 1 LicensePlate, 10.0ms
# image 8/37 /content/KSRTC-Dataset-Split/test/images/Img_32.jpg: 640x640 1 LicensePlate, 9.2ms
# ...
